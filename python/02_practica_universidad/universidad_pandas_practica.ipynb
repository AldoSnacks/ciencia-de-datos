# %%
import pandas as pd

# %%
df = pd.read_csv("universidad.csv")

# %%
df.head()
# Out:
#    id_alumno          nombre  edad fecha_nacimiento       carrera  semestre  \
# 0          1       Ana Lopez    20       2004-03-15    Ingenieria         4
# 1          2     Carlos Ruiz    22       2002-07-10      Medicina         6
# 2          3  Sofia Martinez    19       2005-01-22       Derecho         2
# 3          4      Juan Perez    21       2003-11-05    Ingenieria         5
# 4          5     Laura Gomez    23       2001-05-30  Arquitectura         7
#
#    promedio       ciudad
# 0       8.7         CDMX
# 1       9.1  Guadalajara
# 2       8.3         CDMX
# 3       7.9    Monterrey
# 4       8.8       Puebla

# %%
#Muestra las primeras 5 filas
df.head()
# Out:
#    id_alumno          nombre  edad fecha_nacimiento       carrera  semestre  \
# 0          1       Ana Lopez    20       2004-03-15    Ingenieria         4
# 1          2     Carlos Ruiz    22       2002-07-10      Medicina         6
# 2          3  Sofia Martinez    19       2005-01-22       Derecho         2
# 3          4      Juan Perez    21       2003-11-05    Ingenieria         5
# 4          5     Laura Gomez    23       2001-05-30  Arquitectura         7
#
#    promedio       ciudad
# 0       8.7         CDMX
# 1       9.1  Guadalajara
# 2       8.3         CDMX
# 3       7.9    Monterrey
# 4       8.8       Puebla

# %%
#muestra las 3 primeras filas
df.head(3)
# Out:
#    id_alumno          nombre  edad fecha_nacimiento     carrera  semestre  \
# 0          1       Ana Lopez    20       2004-03-15  Ingenieria         4
# 1          2     Carlos Ruiz    22       2002-07-10    Medicina         6
# 2          3  Sofia Martinez    19       2005-01-22     Derecho         2
#
#    promedio       ciudad
# 0       8.7         CDMX
# 1       9.1  Guadalajara
# 2       8.3         CDMX

# %%
#Muestra la primera fila
df.head(1)
# Out:
#    id_alumno     nombre  edad fecha_nacimiento     carrera  semestre  \
# 0          1  Ana Lopez    20       2004-03-15  Ingenieria         4
#
#    promedio ciudad
# 0       8.7   CDMX

# %%
#Muestra las ultimas 5 filas
df.tail()
# Out:
#    id_alumno         nombre  edad fecha_nacimiento       carrera  semestre  \
# 5          6  Miguel Torres    20       2004-09-12      Medicina         4
# 6          7   Daniela Cruz    22       2002-02-18       Derecho         6
# 7          8  Pedro Sanchez    24       2000-12-01    Ingenieria         8
# 8          9  Valeria Ortiz    21       2003-06-25  Arquitectura         5
# 9         10    Jorge Ramos    19       2005-08-14    Ingenieria         2
#
#    promedio       ciudad
# 5       9.0         CDMX
# 6       8.1  Guadalajara
# 7       7.5    Monterrey
# 8       8.9         CDMX
# 9       8.0       Puebla

# %%
df.head(-5)
# Out:
#    id_alumno          nombre  edad fecha_nacimiento       carrera  semestre  \
# 0          1       Ana Lopez    20       2004-03-15    Ingenieria         4
# 1          2     Carlos Ruiz    22       2002-07-10      Medicina         6
# 2          3  Sofia Martinez    19       2005-01-22       Derecho         2
# 3          4      Juan Perez    21       2003-11-05    Ingenieria         5
# 4          5     Laura Gomez    23       2001-05-30  Arquitectura         7
#
#    promedio       ciudad
# 0       8.7         CDMX
# 1       9.1  Guadalajara
# 2       8.3         CDMX
# 3       7.9    Monterrey
# 4       8.8       Puebla

# %%
#guarda el dataframe en una variable nueva llamada datos
datos = df

# %%
datos.head()
# Out:
#    id_alumno          nombre  edad fecha_nacimiento       carrera  semestre  \
# 0          1       Ana Lopez    20       2004-03-15    Ingenieria         4
# 1          2     Carlos Ruiz    22       2002-07-10      Medicina         6
# 2          3  Sofia Martinez    19       2005-01-22       Derecho         2
# 3          4      Juan Perez    21       2003-11-05    Ingenieria         5
# 4          5     Laura Gomez    23       2001-05-30  Arquitectura         7
#
#    promedio       ciudad
# 0       8.7         CDMX
# 1       9.1  Guadalajara
# 2       8.3         CDMX
# 3       7.9    Monterrey
# 4       8.8       Puebla

# %%
#consulta los tipos de datos
datos.dtypes
# Out:
# id_alumno             int64
# nombre               object
# edad                  int64
# fecha_nacimiento     object
# carrera              object
# semestre              int64
# promedio            float64
# ciudad               object
# dtype: object

# %%
tipos_datos = datos.dtypes

# %%
tipos_datos
# Out:
# id_alumno             int64
# nombre               object
# edad                  int64
# fecha_nacimiento     object
# carrera              object
# semestre              int64
# promedio            float64
# ciudad               object
# dtype: object

# %%
#IMPRIME los tipos de datos
print(tipos_datos)
# Out:
# id_alumno             int64
# nombre               object
# edad                  int64
# fecha_nacimiento     object
# carrera              object
# semestre              int64
# promedio            float64
# ciudad               object
# dtype: object

# %%
#identifica columnas numericas
df.select_dtypes(include="number").columns
# Out:
# Index(['id_alumno', 'edad', 'semestre', 'promedio'], dtype='object')

# %%
df.head()
# Out:
#    id_alumno          nombre  edad fecha_nacimiento       carrera  semestre  \
# 0          1       Ana Lopez    20       2004-03-15    Ingenieria         4
# 1          2     Carlos Ruiz    22       2002-07-10      Medicina         6
# 2          3  Sofia Martinez    19       2005-01-22       Derecho         2
# 3          4      Juan Perez    21       2003-11-05    Ingenieria         5
# 4          5     Laura Gomez    23       2001-05-30  Arquitectura         7
#
#    promedio       ciudad
# 0       8.7         CDMX
# 1       9.1  Guadalajara
# 2       8.3         CDMX
# 3       7.9    Monterrey
# 4       8.8       Puebla

# %%
df.dtypes
# Out:
# id_alumno             int64
# nombre               object
# edad                  int64
# fecha_nacimiento     object
# carrera              object
# semestre              int64
# promedio            float64
# ciudad               object
# dtype: object

# %%
tipos_datos
# Out:
# id_alumno             int64
# nombre               object
# edad                  int64
# fecha_nacimiento     object
# carrera              object
# semestre              int64
# promedio            float64
# ciudad               object
# dtype: object

# %%
#IDENTIFICA COLUMNAS DE TEXTO
datos.select_dtypes(include="object")
# Out:
#            nombre fecha_nacimiento       carrera       ciudad
# 0       Ana Lopez       2004-03-15    Ingenieria         CDMX
# 1     Carlos Ruiz       2002-07-10      Medicina  Guadalajara
# 2  Sofia Martinez       2005-01-22       Derecho         CDMX
# 3      Juan Perez       2003-11-05    Ingenieria    Monterrey
# 4     Laura Gomez       2001-05-30  Arquitectura       Puebla
# 5   Miguel Torres       2004-09-12      Medicina         CDMX
# 6    Daniela Cruz       2002-02-18       Derecho  Guadalajara
# 7   Pedro Sanchez       2000-12-01    Ingenieria    Monterrey
# 8   Valeria Ortiz       2003-06-25  Arquitectura         CDMX
# 9     Jorge Ramos       2005-08-14    Ingenieria       Puebla

# %%
datos.select_dtypes(include="object").columns
# Out:
# Index(['nombre', 'fecha_nacimiento', 'carrera', 'ciudad'], dtype='object')

# %%
datos.head(1)
# Out:
#    id_alumno     nombre  edad fecha_nacimiento     carrera  semestre  \
# 0          1  Ana Lopez    20       2004-03-15  Ingenieria         4
#
#    promedio ciudad
# 0       8.7   CDMX

# %%
datos.dtypes
# Out:
# id_alumno             int64
# nombre               object
# edad                  int64
# fecha_nacimiento     object
# carrera              object
# semestre              int64
# promedio            float64
# ciudad               object
# dtype: object

# %%
df['promedio'].dtypes
# Out:
# dtype('float64')

# %%
df["promedio"].dtypes
# Out:
# dtype('float64')

# %%
#tipo de dato de promedio
df["promedio"].dtypes
# Out:
# dtype('float64')

# %%
df.dtypes["fecha_nacimiento"]
# Out:
# dtype('O')

# %%
datos.dtypes["promedio"]
# Out:
# dtype('float64')

# %%
datos.dtypes["fecha_nacimiento"]
# Out:
# dtype('O')

# %%
#tipo de dato fecha de nacimiento
datos["fecha_nacimiento"].dtypes
# Out:
# dtype('O')

# %%
df["fecha_nacimiento"].dtype
# Out:
# dtype('O')

# %%
tipos_datos
# Out:
# id_alumno             int64
# nombre               object
# edad                  int64
# fecha_nacimiento     object
# carrera              object
# semestre              int64
# promedio            float64
# ciudad               object
# dtype: object

# %%
#cuenta cuantas columnas hay
len(datos.columns)
# Out:
# 8

# %%
datos
# Out:
#    id_alumno          nombre  edad fecha_nacimiento       carrera  semestre  \
# 0          1       Ana Lopez    20       2004-03-15    Ingenieria         4
# 1          2     Carlos Ruiz    22       2002-07-10      Medicina         6
# 2          3  Sofia Martinez    19       2005-01-22       Derecho         2
# 3          4      Juan Perez    21       2003-11-05    Ingenieria         5
# 4          5     Laura Gomez    23       2001-05-30  Arquitectura         7
# 5          6   Miguel Torres    20       2004-09-12      Medicina         4
# 6          7    Daniela Cruz    22       2002-02-18       Derecho         6
# 7          8   Pedro Sanchez    24       2000-12-01    Ingenieria         8
# 8          9   Valeria Ortiz    21       2003-06-25  Arquitectura         5
# 9         10     Jorge Ramos    19       2005-08-14    Ingenieria         2
#
#    promedio       ciudad
# 0       8.7         CDMX
# 1       9.1  Guadalajara
# 2       8.3         CDMX
# 3       7.9    Monterrey
# ...

# %%
#lista de nombres
lista_nombres = datos["nombre"]

# %%
lista_nombres
# Out:
# 0         Ana Lopez
# 1       Carlos Ruiz
# 2    Sofia Martinez
# 3        Juan Perez
# 4       Laura Gomez
# 5     Miguel Torres
# 6      Daniela Cruz
# 7     Pedro Sanchez
# 8     Valeria Ortiz
# 9       Jorge Ramos
# Name: nombre, dtype: object

# %%
lista_nombres = datos["nombre"].tolist()

# %%
lista_nombres
# Out:
# ['Ana Lopez',
#  'Carlos Ruiz',
#  'Sofia Martinez',
#  'Juan Perez',
#  'Laura Gomez',
#  'Miguel Torres',
#  'Daniela Cruz',
#  'Pedro Sanchez',
#  'Valeria Ortiz',
#  'Jorge Ramos']

# %%
tipos_datos
# Out:
# id_alumno             int64
# nombre               object
# edad                  int64
# fecha_nacimiento     object
# carrera              object
# semestre              int64
# promedio            float64
# ciudad               object
# dtype: object

# %%
datos
# Out:
#    id_alumno          nombre  edad fecha_nacimiento       carrera  semestre  \
# 0          1       Ana Lopez    20       2004-03-15    Ingenieria         4
# 1          2     Carlos Ruiz    22       2002-07-10      Medicina         6
# 2          3  Sofia Martinez    19       2005-01-22       Derecho         2
# 3          4      Juan Perez    21       2003-11-05    Ingenieria         5
# 4          5     Laura Gomez    23       2001-05-30  Arquitectura         7
# 5          6   Miguel Torres    20       2004-09-12      Medicina         4
# 6          7    Daniela Cruz    22       2002-02-18       Derecho         6
# 7          8   Pedro Sanchez    24       2000-12-01    Ingenieria         8
# 8          9   Valeria Ortiz    21       2003-06-25  Arquitectura         5
# 9         10     Jorge Ramos    19       2005-08-14    Ingenieria         2
#
#    promedio       ciudad
# 0       8.7         CDMX
# 1       9.1  Guadalajara
# 2       8.3         CDMX
# 3       7.9    Monterrey
# ...

# %%
datos["carrera"].tolist()
# Out:
# ['Ingenieria',
#  'Medicina',
#  'Derecho',
#  'Ingenieria',
#  'Arquitectura',
#  'Medicina',
#  'Derecho',
#  'Ingenieria',
#  'Arquitectura',
#  'Ingenieria']

# %%
datos.dtypes
# Out:
# id_alumno             int64
# nombre               object
# edad                  int64
# fecha_nacimiento     object
# carrera              object
# semestre              int64
# promedio            float64
# ciudad               object
# dtype: object

# %%
lista_carreras = datos["carrera"].tolist()

# %%
lista_carreras
# Out:
# ['Ingenieria',
#  'Medicina',
#  'Derecho',
#  'Ingenieria',
#  'Arquitectura',
#  'Medicina',
#  'Derecho',
#  'Ingenieria',
#  'Arquitectura',
#  'Ingenieria']

# %%
tipos_datos
# Out:
# id_alumno             int64
# nombre               object
# edad                  int64
# fecha_nacimiento     object
# carrera              object
# semestre              int64
# promedio            float64
# ciudad               object
# dtype: object

# %%
lista_promedios = datos["promedio"].tolist()

# %%
lista_promedios
# Out:
# [8.7, 9.1, 8.3, 7.9, 8.8, 9.0, 8.1, 7.5, 8.9, 8.0]

# %%
lista_edades = datos["edad"].tolist()

# %%
lista_edades
# Out:
# [20, 22, 19, 21, 23, 20, 22, 24, 21, 19]

# %%
lista_nombres
# Out:
# ['Ana Lopez',
#  'Carlos Ruiz',
#  'Sofia Martinez',
#  'Juan Perez',
#  'Laura Gomez',
#  'Miguel Torres',
#  'Daniela Cruz',
#  'Pedro Sanchez',
#  'Valeria Ortiz',
#  'Jorge Ramos']

# %%
lista_nombres[0]
# Out:
# 'Ana Lopez'

# %%
#ultimo nombre
lista_nombres[-1]
# Out:
# 'Jorge Ramos'

# %%
min(lista_promedios)
# Out:
# 7.5

# %%
lista_carreras
# Out:
# ['Ingenieria',
#  'Medicina',
#  'Derecho',
#  'Ingenieria',
#  'Arquitectura',
#  'Medicina',
#  'Derecho',
#  'Ingenieria',
#  'Arquitectura',
#  'Ingenieria']

# %%
len(datos["carrera"].tolist())
# Out:
# 10

# %%
len(lista_carreras)
# Out:
# 10

# %%
lista_edades[:3]
# Out:
# [20, 22, 19]

# %%
df["edad"].tolist()
# Out:
# [20, 22, 19, 21, 23, 20, 22, 24, 21, 19]

# %%
datos["edad"].tolist()[:3]
# Out:
# [20, 22, 19]

# %%
lista_edades[:3]
# Out:
# [20, 22, 19]

# %%
df.head()
# Out:
#    id_alumno          nombre  edad fecha_nacimiento       carrera  semestre  \
# 0          1       Ana Lopez    20       2004-03-15    Ingenieria         4
# 1          2     Carlos Ruiz    22       2002-07-10      Medicina         6
# 2          3  Sofia Martinez    19       2005-01-22       Derecho         2
# 3          4      Juan Perez    21       2003-11-05    Ingenieria         5
# 4          5     Laura Gomez    23       2001-05-30  Arquitectura         7
#
#    promedio       ciudad
# 0       8.7         CDMX
# 1       9.1  Guadalajara
# 2       8.3         CDMX
# 3       7.9    Monterrey
# 4       8.8       Puebla

# %%
df.columns
# Out:
# Index(['id_alumno', 'nombre', 'edad', 'fecha_nacimiento', 'carrera',
#        'semestre', 'promedio', 'ciudad'],
#       dtype='object')

# %%
lista_ciudades = datos["ciudad"].tolist()

# %%
lista_ciudades
# Out:
# ['CDMX',
#  'Guadalajara',
#  'CDMX',
#  'Monterrey',
#  'Puebla',
#  'CDMX',
#  'Guadalajara',
#  'Monterrey',
#  'CDMX',
#  'Puebla']

# %%
aprobacion = {"promedio_aprobatorio":7}

# %%
aprobacion
# Out:
# {'promedio_aprobatorio': 7}

# %%
#diccionario total de alumnos
total_alumnos = {"Total": len(df)}

# %%
len(df)
# Out:
# 10

# %%
datos
# Out:
#    id_alumno          nombre  edad fecha_nacimiento       carrera  semestre  \
# 0          1       Ana Lopez    20       2004-03-15    Ingenieria         4
# 1          2     Carlos Ruiz    22       2002-07-10      Medicina         6
# 2          3  Sofia Martinez    19       2005-01-22       Derecho         2
# 3          4      Juan Perez    21       2003-11-05    Ingenieria         5
# 4          5     Laura Gomez    23       2001-05-30  Arquitectura         7
# 5          6   Miguel Torres    20       2004-09-12      Medicina         4
# 6          7    Daniela Cruz    22       2002-02-18       Derecho         6
# 7          8   Pedro Sanchez    24       2000-12-01    Ingenieria         8
# 8          9   Valeria Ortiz    21       2003-06-25  Arquitectura         5
# 9         10     Jorge Ramos    19       2005-08-14    Ingenieria         2
#
#    promedio       ciudad
# 0       8.7         CDMX
# 1       9.1  Guadalajara
# 2       8.3         CDMX
# 3       7.9    Monterrey
# ...

# %%
#diccionario carreras
dic_carreras = {"total carreras": datos["carrera"].unique().tolist()}

# %%
dic_carreras
# Out:
# {'total carreras': ['Ingenieria', 'Medicina', 'Derecho', 'Arquitectura']}

# %%
datos["carrera"].tolist()
# Out:
# ['Ingenieria',
#  'Medicina',
#  'Derecho',
#  'Ingenieria',
#  'Arquitectura',
#  'Medicina',
#  'Derecho',
#  'Ingenieria',
#  'Arquitectura',
#  'Ingenieria']

# %%
datos["carrera"].unique()
# Out:
# array(['Ingenieria', 'Medicina', 'Derecho', 'Arquitectura'], dtype=object)

# %%
datos["carrera"].unique().tolist()
# Out:
# ['Ingenieria', 'Medicina', 'Derecho', 'Arquitectura']

# %%
dic_carreras
# Out:
# {'total carreras': ['Ingenieria', 'Medicina', 'Derecho', 'Arquitectura']}

# %%
lista_ciudades
# Out:
# ['CDMX',
#  'Guadalajara',
#  'CDMX',
#  'Monterrey',
#  'Puebla',
#  'CDMX',
#  'Guadalajara',
#  'Monterrey',
#  'CDMX',
#  'Puebla']

# %%
lista_ciudades
# Out:
# ['CDMX',
#  'Guadalajara',
#  'CDMX',
#  'Monterrey',
#  'Puebla',
#  'CDMX',
#  'Guadalajara',
#  'Monterrey',
#  'CDMX',
#  'Puebla']

# %%
datos["ciudad"]
# Out:
# 0           CDMX
# 1    Guadalajara
# 2           CDMX
# 3      Monterrey
# 4         Puebla
# 5           CDMX
# 6    Guadalajara
# 7      Monterrey
# 8           CDMX
# 9         Puebla
# Name: ciudad, dtype: object

# %%
datos["ciudad"].unique()
# Out:
# array(['CDMX', 'Guadalajara', 'Monterrey', 'Puebla'], dtype=object)

# %%
datos["ciudad"].unique().tolist()
# Out:
# ['CDMX', 'Guadalajara', 'Monterrey', 'Puebla']

# %%
lista_ciudades
# Out:
# ['CDMX',
#  'Guadalajara',
#  'CDMX',
#  'Monterrey',
#  'Puebla',
#  'CDMX',
#  'Guadalajara',
#  'Monterrey',
#  'CDMX',
#  'Puebla']

# %%
dic_ciudades = {"total ciudades": datos["ciudad"].unique().tolist()}

# %%
dic_ciudades
# Out:
# {'total ciudades': ['CDMX', 'Guadalajara', 'Monterrey', 'Puebla']}

# %%
df["promedio"].min()
# Out:
# np.float64(7.5)

# %%
dic_promedio_min = {"minimo": datos["promedio"].min()}

# %%
dic_promedio_min
# Out:
# {'minimo': np.float64(7.5)}

# %%
dic_promedio_min["minimo"]
# Out:
# np.float64(7.5)

# %%
#alumnos por carrera
datos["carrera"].value_counts()
# Out:
# carrera
# Ingenieria      4
# Medicina        2
# Derecho         2
# Arquitectura    2
# Name: count, dtype: int64

# %%
datos["carrera"].value_counts("Medicina")
# Out:
# carrera
# Ingenieria      0.4
# Medicina        0.2
# Derecho         0.2
# Arquitectura    0.2
# Name: proportion, dtype: float64

# %%
#alumnos por ciudad
datos["ciudad"].value_counts()
# Out:
# ciudad
# CDMX           4
# Guadalajara    2
# Monterrey      2
# Puebla         2
# Name: count, dtype: int64

# %%
df.head(9)
# Out:
#    id_alumno          nombre  edad fecha_nacimiento       carrera  semestre  \
# 0          1       Ana Lopez    20       2004-03-15    Ingenieria         4
# 1          2     Carlos Ruiz    22       2002-07-10      Medicina         6
# 2          3  Sofia Martinez    19       2005-01-22       Derecho         2
# 3          4      Juan Perez    21       2003-11-05    Ingenieria         5
# 4          5     Laura Gomez    23       2001-05-30  Arquitectura         7
# 5          6   Miguel Torres    20       2004-09-12      Medicina         4
# 6          7    Daniela Cruz    22       2002-02-18       Derecho         6
# 7          8   Pedro Sanchez    24       2000-12-01    Ingenieria         8
# 8          9   Valeria Ortiz    21       2003-06-25  Arquitectura         5
#
#    promedio       ciudad
# 0       8.7         CDMX
# 1       9.1  Guadalajara
# 2       8.3         CDMX
# 3       7.9    Monterrey
# 4       8.8       Puebla
# 5       9.0         CDMX
# ...

# %%
df["semestre"].value_counts()
# Out:
# semestre
# 4    2
# 6    2
# 2    2
# 5    2
# 7    1
# 8    1
# Name: count, dtype: int64

# %%
#carreras ordenadas
datos["carrera"].value_counts()
# Out:
# carrera
# Ingenieria      4
# Medicina        2
# Derecho         2
# Arquitectura    2
# Name: count, dtype: int64

# %%
datos["carrera"].value_counts().sort_values(ascending=True)
# Out:
# carrera
# Medicina        2
# Derecho         2
# Arquitectura    2
# Ingenieria      4
# Name: count, dtype: int64

# %%
datos["carrera"].sort_values(ascending=True)
# Out:
# 4    Arquitectura
# 8    Arquitectura
# 2         Derecho
# 6         Derecho
# 0      Ingenieria
# 3      Ingenieria
# 7      Ingenieria
# 9      Ingenieria
# 1        Medicina
# 5        Medicina
# Name: carrera, dtype: object

# %%
#porcentaje por carrera
datos["carrera"].value_counts(normalize=True)
# Out:
# carrera
# Ingenieria      0.4
# Medicina        0.2
# Derecho         0.2
# Arquitectura    0.2
# Name: proportion, dtype: float64

# %%
datos["carrera"].value_counts(normalize=True) * 100
# Out:
# carrera
# Ingenieria      40.0
# Medicina        20.0
# Derecho         20.0
# Arquitectura    20.0
# Name: proportion, dtype: float64
